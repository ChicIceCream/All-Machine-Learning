# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
df = pd.read_csv("height_weight_linear_regression.csv")

# %%
df.head()
# Out:
#    Height (cm)  Weight (kg)
# 0   187.640523    93.853989
# 1   174.001572    71.561912
# 2   179.787380    74.551896
# 3   192.408932    91.431003
# 4   188.675580    79.038394

# %%
## Scatter plot

plt.scatter(df["Weight (kg)"], df["Height (cm)"])
plt.xlabel("Weight")
plt.ylabel("Height")
# Out:
# Text(0, 0.5, 'Height')

# %%
df.corr()
# Out:
#              Height (cm)  Weight (kg)
# Height (cm)     1.000000     0.705211
# Weight (kg)     0.705211     1.000000

# %%
## Seaborn visualisation
import seaborn as sns
sns.pairplot(df)
# Out:
# E:\Anaconda\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
# independant and dependant features
X = df[["Weight (kg)"]] #indepedant feature should be in 2 bracakets
Y = df["Height (cm)"]

# %%
X.head()
# Out:
#    Weight (kg)
# 0    93.853989
# 1    71.561912
# 2    74.551896
# 3    91.431003
# 4    79.038394
